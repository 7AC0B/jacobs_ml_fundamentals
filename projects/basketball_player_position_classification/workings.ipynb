# %%
import pandas as pd
import os

# %%
player_stats_df = pd.read_csv('data/totals_stats.csv')
player_stats_df
# Out:
#         Season Age Team   Lg     G      MP     FG    FGA    FG%    3P  ...  \
# 0      1970-71  26  PTC  ABA   9.0    57.0    3.0   12.0  0.250   0.0  ...
# 1      2010-11  24  MIN  NBA  42.0   419.0   55.0  154.0  0.357  17.0  ...
# 2      2011-12  25  OKC  NBA  26.0   141.0   13.0   38.0  0.342   4.0  ...
# 3      2012-13  26  MIN  NBA   4.0    31.0    2.0   10.0  0.200   0.0  ...
# 4      2019-20  23  SAC  NBA  36.0   232.0   35.0   84.0  0.417   9.0  ...
# ...        ...  ..  ...  ...   ...     ...    ...    ...    ...   ...  ...
# 35691  2000-01  24  CHH  NBA  67.0  1201.0  216.0  407.0  0.531   2.0  ...
# 35692  2001-02  25  CHI  NBA  29.0   653.0  112.0  247.0  0.453   2.0  ...
# 35693  2002-03  26  CHI  NBA  64.0  1355.0  155.0  315.0  0.492   3.0  ...
# 35694  2003-04  27  CHI  NBA  51.0  1024.0  157.0  326.0  0.482   1.0  ...
# 35695  1988-89  22  NJN  NBA  37.0   307.0   50.0  102.0  0.490   0.0  ...
#
# ...
